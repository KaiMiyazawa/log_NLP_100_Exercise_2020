# %% [markdown]
# ## 50. データの入手・整形Permalink
# News Aggregator Data Setをダウンロードし、以下の要領で学習データ（train.txt），検証データ（valid.txt），評価データ（test.txt）を作成せよ．
#
# - ダウンロードしたzipファイルを解凍し，readme.txtの説明を読む．
# - 情報源（publisher）が”Reuters”, “Huffington Post”, “Businessweek”, “Contactmusic.com”, “Daily Mail”の事例（記事）のみを抽出する．
# - 抽出された事例をランダムに並び替える．
# - 抽出された事例の80%を学習データ，残りの10%ずつを検証データと評価データに分割し，それぞれtrain.txt，valid.txt，test.txtというファイル名で保存する．ファイルには，１行に１事例を書き出すこととし，カテゴリ名と記事見出しのタブ区切り形式とせよ（このファイルは後に問題70で再利用する）．
# - 学習データと評価データを作成したら，各カテゴリの事例数を確認せよ．

# %%
import pandas as pd
data = pd.read_table('newsCorpora.csv', sep='\t')
data
# Out:
#              1  \
# 0            2
# 1            3
# 2            4
# 3            5
# 4            6
# ...        ...
# 422413  422933
# 422414  422934
# 422415  422935
# 422416  422936
# 422417  422937
#
#        Fed official says weak data caused by weather, should not slow taper  \
# 0       Fed's Charles Plosser sees high bar for change...
# 1       US open: Stocks fall after Fed official hints ...
# 2       Fed risks falling 'behind the curve', Charles ...
# 3       Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 4       Plosser: Fed May Have to Accelerate Tapering Pace
# ...                                                   ...
# 422413  Surgeons to remove 4-year-old's rib to rebuild...
# 422414  Boy to have surgery on esophagus after battery...
# 422415  Child who swallowed battery to have reconstruc...
# 422416  Phoenix boy undergoes surgery to repair throat...
# 422417  Phoenix boy undergoes surgery to repair throat...
#
#        http://www.latimes.com/business/money/la-fi-mo-federal-reserve-plosser-stimulus-economy-20140310,0,1312750.story\?track=rss  \
# 0       http://www.livemint.com/Politics/H2EvwJSK2VE6O...
# 1       http://www.ifamagazine.com/news/us-open-stocks...
# 2       http://www.ifamagazine.com/news/fed-risks-fall...
# 3       http://www.moneynews.com/Economy/federal-reser...
# 4       http://www.nasdaq.com/article/plosser-fed-may-...
# ...                                                   ...
# 422413  http://www.cbs3springfield.com/story/26378648/...
# 422414  http://www.wlwt.com/news/boy-to-have-surgery-o...
# 422415  http://www.newsnet5.com/news/local-news/child-...
# 422416  http://www.wfsb.com/story/26368078/phoenix-boy...
# 422417  http://www.cbs3springfield.com/story/26368078/...
#
#        Los Angeles Times  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM  \
# 0               Livemint  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 1           IFA Magazine  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 2           IFA Magazine  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 3              Moneynews  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 4                 NASDAQ  b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# ...                  ... ..                            ...
# 422413           WSHM-TV  m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422414   WLWT Cincinnati  m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422415      NewsNet5.com  m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422416              WFSB  m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422417           WSHM-TV  m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
#
#                 www.latimes.com  1394470370698
# 0              www.livemint.com  1394470371207
# 1           www.ifamagazine.com  1394470371550
# 2           www.ifamagazine.com  1394470371793
# 3             www.moneynews.com  1394470372027
# 4                www.nasdaq.com  1394470372212
# ...                         ...            ...
# 422413  www.cbs3springfield.com  1409229190251
# 422414             www.wlwt.com  1409229190508
# 422415         www.newsnet5.com  1409229190771
# 422416             www.wfsb.com  1409229191071
# 422417  www.cbs3springfield.com  1409229191565
#
# [422418 rows x 8 columns]
